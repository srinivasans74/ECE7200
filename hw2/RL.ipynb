# %%
import numpy as np
import matplotlib.pyplot as plt
import os
S=11
vs=np.zeros(12)

sum_vs=0
delta=1
epsilon=0.0001
vfin=0
s=[]
convergence=False
iter=0

def pat1():
    vs[0]=-1+0.25*2*vs[0]+0.25*vs[1]+0.25*vs[3]
    vs[1]=-1+0.25*vs[2]+0.25*vs[0]+0.25*2*vs[1]
    vs[2]=-1+0.25*vs[4]+0.25*vs[1]+0.25*2*vs[2]
    vs[3]=-1+0.25*vs[0]+0.25*vs[5]+0.25*2*vs[3]
    vs[4]=-1+0.25*vs[2]+0.25*vs[7]+0.25*2*vs[4]
    vs[5]=-1+0.25*vs[6]+0.25*vs[8]+0.25*vs[3]+0.25*vs[5]
    vs[6]=-1+0.25*vs[6]+0.25*vs[7]+0.25*vs[9]+0.25*vs[5]
    vs[7]=-1+0.25*vs[7]+0.25*vs[4]+0.25*vs[6]+0.25*vs[10]
    vs[8]=-1+0.25*2*vs[8]+0.25*vs[9]+0.25*vs[5]
    vs[9]=-10+vs[11]
    vs[10]=10+vs[11]
    vs[11]=0

def pat2():
    vs[5]=-1+0.25*vs[6]+0.25*vs[8]+0.25*vs[3]+0.25*vs[5]
    vs[6]=-1+0.25*vs[6]+0.25*vs[7]+0.25*vs[9]+0.25*vs[5]
    vs[7]=-1+0.25*vs[7]+0.25*vs[4]+0.25*vs[6]+0.25*vs[10]
    vs[8]=-1+0.25*2*vs[8]+0.25*vs[9]+0.25*vs[5]
    vs[9]=-10+vs[11]
    vs[10]=10+vs[11]
    vs[11]=0
    vs[0]=-1+0.25*2*vs[0]+0.25*vs[1]+0.25*vs[3]
    vs[1]=-1+0.25*vs[2]+0.25*vs[0]+0.25*2*vs[1]
    vs[2]=-1+0.25*vs[4]+0.25*vs[1]+0.25*2*vs[2]
    vs[3]=-1+0.25*vs[0]+0.25*vs[5]+0.25*2*vs[3]
    vs[4]=-1+0.25*vs[2]+0.25*vs[7]+0.25*2*vs[4]

while(delta>epsilon):
    Vin=vfin
    delta=0
    pat1()
    vfin=np.sum(vs)
    delta=max(delta,abs(Vin-vfin))
    vx=vs
    s_list = vx.tolist()
    s.append(s_list)
    iter=iter+1
print(iter)
print(s[20])
# Out:
# 227
# [-22.384263249169795, -21.98914193391379, -19.593900000130805, -21.389270069927118, -14.841814525134032, -17.772611580678266, -12.849976208882792, -7.161645520134616, -15.723690891277267, -10.0, 10.0, 0.0]

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
S=11
vs=np.zeros(12)

sum_vs=0
delta=1
epsilon=0.0001
vfin=0
s=[]
convergence=False
iter=0

def pat1():
    vs[0]=-1+0.25*2*vs[0]+0.25*vs[1]+0.25*vs[3]
    vs[1]=-1+0.25*vs[2]+0.25*vs[0]+0.25*2*vs[1]
    vs[2]=-1+0.25*vs[4]+0.25*vs[1]+0.25*2*vs[2]
    vs[3]=-1+0.25*vs[0]+0.25*vs[5]+0.25*2*vs[3]
    vs[4]=-1+0.25*vs[2]+0.25*vs[7]+0.25*2*vs[4]
    vs[5]=-1+0.25*vs[6]+0.25*vs[8]+0.25*vs[3]+0.25*vs[5]
    vs[6]=-1+0.25*vs[6]+0.25*vs[7]+0.25*vs[9]+0.25*vs[5]
    vs[7]=-1+0.25*vs[7]+0.25*vs[4]+0.25*vs[6]+0.25*vs[10]
    vs[8]=-1+0.25*2*vs[8]+0.25*vs[9]+0.25*vs[5]
    vs[9]=-10+vs[11]
    vs[10]=10+vs[11]
    vs[11]=0

def pat2():
    vs[5]=-1+0.25*vs[6]+0.25*vs[8]+0.25*vs[3]+0.25*vs[5]
    vs[6]=-1+0.25*vs[6]+0.25*vs[7]+0.25*vs[9]+0.25*vs[5]
    vs[7]=-1+0.25*vs[7]+0.25*vs[4]+0.25*vs[6]+0.25*vs[10]
    vs[8]=-1+0.25*2*vs[8]+0.25*vs[9]+0.25*vs[5]
    vs[9]=-10+vs[11]
    vs[10]=10+vs[11]
    vs[11]=0
    vs[0]=-1+0.25*2*vs[0]+0.25*vs[1]+0.25*vs[3]
    vs[1]=-1+0.25*vs[2]+0.25*vs[0]+0.25*2*vs[1]
    vs[2]=-1+0.25*vs[4]+0.25*vs[1]+0.25*2*vs[2]
    vs[3]=-1+0.25*vs[0]+0.25*vs[5]+0.25*2*vs[3]
    vs[4]=-1+0.25*vs[2]+0.25*vs[7]+0.25*2*vs[4]

while(delta>epsilon):
    Vin=vfin
    delta=0
    pat2()
    vfin=np.sum(vs)
    delta=max(delta,abs(Vin-vfin))
    vx=vs
    s_list = vx.tolist()
    s.append(s_list)
    iter=iter+1
print(iter)
print(s[20])
# Out:
# 227
# [-22.580910262573436, -22.181067476761235, -19.756055685189853, -21.547068849360677, -14.956633652150241, -17.56474861224889, -12.726482878305896, -7.013410130474744, -15.614205048914174, -10.0, 10.0, 0.0]

# %%
epsilon = 0.1 
K = 100 
ssax=[]
delta=1
vs=np.zeros(12)
for k in range(1, K+1):
    Vin = vfin
    delta = 0
    pat2()
    vfin = np.sum(vs)
    delta = max(delta, abs(Vin - vfin))
    vx = vs
    s_lista = vx.tolist()
    ssax.append(s_lista)

    if k % (K // 5) == 0 or k == K:
        print(f"Iteration {k}: {ssax[k-1]}")
# Out:
# Iteration 20: [-21.904654091815146, -21.493024605353256, -19.157310433764998, -21.021308261310192, -14.528534396468185, -17.249090742131667, -12.542559653849796, -6.7986232471248975, -15.446035791703903, -10.0, 10.0, 0.0]
# Iteration 40: [-30.530056538551477, -30.336669411040756, -26.89150225548974, -27.683201035664464, -20.06593274833951, -21.22527317806659, -14.880837840123824, -9.567246669658672, -17.551524576766322, -10.0, 10.0, 0.0]
# Iteration 60: [-33.605050178714976, -33.50325445111076, -29.669046977100418, -30.049956309723715, -22.056472937034556, -22.633862379926782, -15.713685094313902, -10.560835319070991, -18.295098396496567, -10.0, 10.0, 0.0]
# Iteration 80: [-34.70450183542213, -34.63557341181533, -30.662328040326805, -30.89611707906694, -22.76833378205036, -23.137434525358646, -16.01146892059438, -10.916153422949812, -18.56091057943074, -10.0, 10.0, 0.0]
# ...

# %%
epsilon = 0.0001 
K = 1000 
ssax=[]
delta=1
vs=np.zeros(12)
for k in range(1, K+1):
    Vin = vfin
    delta = 0
    pat2()
    vfin = np.sum(vs)
    delta = max(delta, abs(Vin - vfin))
    vx = vs
    s_lista = vx.tolist()
    ssax.append(s_lista)

    if k % (K // 5) == 0 or k == K:
        print(f"Iteration {k}: {ssax[k-1]}")
# Out:
# Iteration 200: [-35.31517656119257, -35.264505407599515, -31.21403425528921, -31.36610416057599, -23.16372875745843, -23.417135649835146, -16.176868739151743, -11.113510661049862, -18.708551507025458, -10.0, 10.0, 0.0]
# Iteration 400: [-35.31645565249269, -35.26582273979349, -31.215189833928626, -31.367088573954998, -23.164556933724402, -23.417721498967367, -16.177215178034707, -11.113924036506807, -18.708860748926078, -10.0, 10.0, 0.0]
# Iteration 600: [-35.31645569620104, -35.26582278480859, -31.21518987341637, -31.36708860759379, -23.16455696202435, -23.41772151898666, -16.177215189873014, -11.113924050632427, -18.708860759493312, -10.0, 10.0, 0.0]
# Iteration 800: [-35.31645569620248, -35.26582278481007, -31.21518987341767, -31.367088607594894, -23.16455696202528, -23.417721518987314, -16.1772151898734, -11.113924050632894, -18.708860759493653, -10.0, 10.0, 0.0]
# ...
